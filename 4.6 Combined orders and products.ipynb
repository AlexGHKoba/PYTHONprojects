# %% [markdown]
# ### import pkl file

# %%
# Import libraries

import pandas as pd
import numpy as np
import os
path = r'C:\Users\User\Instacart Basket Analysis'

df_orders_products_combined=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))
df_prods_clean=pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'prods_clean.csv'), index_col = False)

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           0   2539329        1             1          2                  8
# 1           0   2539329        1             1          2                  8
# 2           0   2539329        1             1          2                  8
# 3           0   2539329        1             1          2                  8
# 4           0   2539329        1             1          2                  8
#
#    days_since_prior_order  days_since_prior_order_Flag  product_id  \
# 0                     NaN                         True         196
# 1                     NaN                         True       14084
# 2                     NaN                         True       12427
# 3                     NaN                         True       26088
# 4                     NaN                         True       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# ...

# %%
# Delete the column _merge as unnessesary any more.
df_orders_products_combined = df_orders_products_combined.drop(columns = ['_merge'])

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           0   2539329        1             1          2                  8
# 1           0   2539329        1             1          2                  8
# 2           0   2539329        1             1          2                  8
# 3           0   2539329        1             1          2                  8
# 4           0   2539329        1             1          2                  8
#
#    days_since_prior_order  days_since_prior_order_Flag  product_id  \
# 0                     NaN                         True         196
# 1                     NaN                         True       14084
# 2                     NaN                         True       12427
# 3                     NaN                         True       26088
# 4                     NaN                         True       26405
#
#    add_to_cart_order  reordered
# 0                  1          0
# 1                  2          0
# ...

# %% [markdown]
# ### Merge with products dataframe and export

# %%
df_prods_clean.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Only common column for both dataframes is 'product_id'. 
df_orders_products_merged = df_prods_clean.merge(df_orders_products_combined, on = 'product_id', indicator = True)

# %%
df_orders_products_merged.shape

# %%
df_orders_products_merged['_merge'].value_counts()

# %%
# Export as .pkl
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
