# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
df = pd.read_csv(r'C:\Users\User\Instacart Basket Analysis\02 Data\Original Data\orders.csv', index_col = False)

# %%
df = pd.read_csv(r'C:\Users\User\Instacart Basket Analysis\02 Data\Original Data\products.csv', index_col = False)

# %%
path = r'C:\Users\User\Instacart Basket Analysis'
path
# Out:
# 'C:\\Users\\User\\Instacart Basket Analysis'

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
df=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df.head(10)
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
# 5   3367565        1    prior             6          2                  7
# 6    550135        1    prior             7          1                  9
# 7   3108588        1    prior             8          1                 14
# 8   2295261        1    prior             9          1                 16
# 9   2550362        1    prior            10          4                  8
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# ...

# %%
df.tail(7)
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421076   2129269   206209    prior             8          3
# 3421077   2558525   206209    prior             9          4
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 3421076                 17                    22.0
# 3421077                 15                    22.0
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0

# %%
df.shape
# Out:
# (3421083, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
import pandas as pd
import numpy as np
import os
path = r'C:\Users\User\Instacart Basket Analysis'
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), usecols = vars_list)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_prods=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_prods.head(25)
# Out:
#     product_id                                       product_name  aisle_id  \
# 0            1                         Chocolate Sandwich Cookies        61
# 1            2                                   All-Seasons Salt       104
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 3            4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4            5                          Green Chile Anytime Sauce         5
# 5            6                                       Dry Nose Oil        11
# 6            7                     Pure Coconut Water With Orange        98
# 7            8                  Cut Russet Potatoes Steam N' Mash       116
# 8            9                  Light Strawberry Blueberry Yogurt       120
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# ...

# %%
df_prods.tail(35)
# Out:
#        product_id                                       product_name  \
# 49658       49654                   Teriyaki Sauce, Sesame, Original
# 49659       49655                                        Apple Cider
# 49660       49656                         Masada Kosher Pocket Bread
# 49661       49657                                  Cabernet Tomatoes
# 49662       49658                         Brie with Herbs Foil Wedge
# 49663       49659                            Organic Creamed Coconut
# 49664       49660                        Professionals Sleek Shampoo
# 49665       49661                                              Porto
# 49666       49662                       Bacon Cheddar Pretzel Pieces
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
# 49668       49664                     Lemon Cayenne Drinking Vinegar
# 49669       49665      Super Dark Coconut Ash & Banana Chocolate Bar
# 49670       49666                      Ginger Snaps Snacking Cookies
# ...

# %%
df_prods.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# The command describe shows a max at aisle_id is 134.

# %%
df_prods.dtypes
# Out:
# product_id         int64
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %% [markdown]
# The command dtypes shows a type for department_id is int64

# %%
df_ords=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %% [markdown]
# Import orders.csv

# %% [markdown]
# # 03. Wrangling procedures

# %%
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %% [markdown]
# Drop columns eval_set

# %% [markdown]
# df_ords = df_ords.drop(columns = ['eval_set'])

# %% [markdown]
# Drop columns eval_set and change the table

# %%
df['days_since_prior_order'].value_counts(dropna = False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %% [markdown]
# shows each value of the variable and counts them (including NaN)

# %%
df.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# Renaming of the column order_dow

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %% [markdown]
# Change type of data

# %%
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %% [markdown]
# Import dataframe departments.csv and show 'head'

# %%
df_dep_t = df_dep.T   # transpose

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# Transpose and display of df_dep

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %% [markdown]
# Added an index column

# %%
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_t[1:]

# %% [markdown]
# copy without row 0

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# df_dep_t_new is the new transposed dataframe

# %%
data_dict = df_dep_t_new.to_dict('index')
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# Dictionary of df_dep_t_new

# %%
data_dict.get('19')
# Out:
# {'department': 'snacks'}

# %%
df_snacks =  df_prods[df_prods['department_id']==19]
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %% [markdown]
# Subsetting

# %% [markdown]
# # 4. Assignment 4.4

# %% [markdown]
# ## Step 2

# %%
df_ords.head()
# Out:
#   order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0  2539329        1    prior             1          2                  8
# 1  2398795        1    prior             2          3                  7
# 2   473747        1    prior             3          3                 12
# 3  2254736        1    prior             4          4                  7
# 4   431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# Order_number we will change to the string format

# %%
df_ords['order_number'] = df_ords['order_number'].astype('str')

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                     int64
# eval_set                   object
# order_number               object
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# ## Step 3

# %%
df_ords.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = False)
# Out:
#         order_id  user_id eval_set order_number  order_day_of_week  \
# 0        2539329        1    prior            1                  2
# 1        2398795        1    prior            2                  3
# 2         473747        1    prior            3                  3
# 3        2254736        1    prior            4                  4
# 4         431534        1    prior            5                  4
# ...          ...      ...      ...          ...                ...
# 3421078  2266710   206209    prior           10                  5
# 3421079  1854736   206209    prior           11                  4
# 3421080   626363   206209    prior           12                  1
# 3421081  2977660   206209    prior           13                  1
# 3421082   272231   206209    train           14                  6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# ...

# %% [markdown]
# Renaming of 'order_dow' to 'order_day_of_week'

# %% [markdown]
# ## Step 4

# %%
df_ords.describe()
# Out:
#             user_id     order_dow  order_hour_of_day  days_since_prior_order
# count  3.421083e+06  3.421083e+06       3.421083e+06            3.214874e+06
# mean   1.029782e+05  2.776219e+00       1.345202e+01            1.111484e+01
# std    5.953372e+04  2.046829e+00       4.226088e+00            9.206737e+00
# min    1.000000e+00  0.000000e+00       0.000000e+00            0.000000e+00
# 25%    5.139400e+04  1.000000e+00       1.000000e+01            4.000000e+00
# 50%    1.026890e+05  3.000000e+00       1.300000e+01            7.000000e+00
# 75%    1.543850e+05  5.000000e+00       1.600000e+01            1.500000e+01
# max    2.062090e+05  6.000000e+00       2.300000e+01            3.000000e+01

# %% [markdown]
# To find the busiest hour for placing orders we need to analyze the 'order_hour_of_day' column. Mean is 13.45 (1:28 PM).
# So, the answer is from 1 PM to 2 PM.

# %% [markdown]
# ## Step 5

# %%
df_prods[df_prods['department_id']==4]
# Out:
#        product_id                                      product_name  aisle_id  \
# 30             31                                White Pearl Onions       123
# 42             43                               Organic Clementines       123
# 44             45                                 European Cucumber        83
# 65             66                         European Style Spring Mix       123
# 88             89                    Yogurt Fruit Dip Sliced Apples       123
# ...           ...                                               ...       ...
# 49582       49578                                Black Garlic Bulbs       123
# 49623       49619                                        Opo Squash        83
# 49639       49635  Baby Food Blueberry, Parsnip & Buckwheat Stage 2        83
# 49661       49657                                 Cabernet Tomatoes        83
# 49687       49683                                    Cucumber Kirby        83
#
#        department_id  prices
# ...

# %% [markdown]
# This is the 1st method.

# %%
df_prods.loc[df_prods['department_id'] == 4]
# Out:
#        product_id                                      product_name  aisle_id  \
# 30             31                                White Pearl Onions       123
# 42             43                               Organic Clementines       123
# 44             45                                 European Cucumber        83
# 65             66                         European Style Spring Mix       123
# 88             89                    Yogurt Fruit Dip Sliced Apples       123
# ...           ...                                               ...       ...
# 49582       49578                                Black Garlic Bulbs       123
# 49623       49619                                        Opo Squash        83
# 49639       49635  Baby Food Blueberry, Parsnip & Buckwheat Stage 2        83
# 49661       49657                                 Cabernet Tomatoes        83
# 49687       49683                                    Cucumber Kirby        83
#
#        department_id  prices
# ...

# %% [markdown]
# This is the 2nd method.

# %%
df_prods.loc[df_prods['department_id'].isin([4])]
# Out:
#        product_id                                      product_name  aisle_id  \
# 30             31                                White Pearl Onions       123
# 42             43                               Organic Clementines       123
# 44             45                                 European Cucumber        83
# 65             66                         European Style Spring Mix       123
# 88             89                    Yogurt Fruit Dip Sliced Apples       123
# ...           ...                                               ...       ...
# 49582       49578                                Black Garlic Bulbs       123
# 49623       49619                                        Opo Squash        83
# 49639       49635  Baby Food Blueberry, Parsnip & Buckwheat Stage 2        83
# 49661       49657                                 Cabernet Tomatoes        83
# 49687       49683                                    Cucumber Kirby        83
#
#        department_id  prices
# ...

# %% [markdown]
# This is the 3rd method.

# %% [markdown]
# ## Step 6

# %% [markdown]
# Breakfast has number 14 in departments_id

# %% [markdown]
# 1st method

# %%
df_breakfast  =  df_prods[df_prods['department_id']==14]
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# 2nd method

# %%
df_breakfast_2  =  df_prods.loc[df_prods['department_id']==14]
df_breakfast_2.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# 3rd method

# %%
df_breakfast_3  =  df_prods.loc[df_prods['department_id'].isin([14])]
df_breakfast_3.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# ## Steps 7,8

# %%
data_dict = df_dep_t_new.to_dict('index')
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# Departments: alcohol - 5, deli - 20, beverages - 7, meat/seafood - 12

# %%
df_party  =  df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]
df_party
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %% [markdown]
# The dataframe df_party contains all data on alcohol, deli, beverages, and meat/seafood.

# %% [markdown]
# The dataframe df_party has 7650 rows.

# %% [markdown]
# ## Step 9

# %%
df_user_id1 =  df_ords[df_ords['user_id']==1]
df_user_id1
# Out:
#    order_id  user_id eval_set order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior            1          2                  8
# 1   2398795        1    prior            2          3                  7
# 2    473747        1    prior            3          3                 12
# 3   2254736        1    prior            4          4                  7
# 4    431534        1    prior            5          4                 15
# 5   3367565        1    prior            6          2                  7
# 6    550135        1    prior            7          1                  9
# 7   3108588        1    prior            8          1                 14
# 8   2295261        1    prior            9          1                 16
# 9   2550362        1    prior           10          4                  8
# 10  1187899        1    train           11          4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %%
df_user_id1.shape
# Out:
# (11, 7)

# %% [markdown]
# ## Step 10

# %%
df_user_id1.describe()
# Out:
#        user_id  order_dow  order_hour_of_day  days_since_prior_order
# count     11.0  11.000000          11.000000               10.000000
# mean       1.0   2.636364          10.090909               19.000000
# std        0.0   1.286291           3.477198                9.030811
# min        1.0   1.000000           7.000000                0.000000
# 25%        1.0   1.500000           7.500000               14.250000
# 50%        1.0   3.000000           8.000000               19.500000
# 75%        1.0   4.000000          13.000000               26.250000
# max        1.0   4.000000          16.000000               30.000000

# %% [markdown]
# That user made 11 orders mostly on Monday/Tuesday near 10 AM. He/she had average time between orders 19 days.

# %% [markdown]
# ## Steps 12, 13

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
